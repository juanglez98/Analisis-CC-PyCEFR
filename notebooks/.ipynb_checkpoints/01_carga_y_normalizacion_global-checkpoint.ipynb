# %% [markdown]
# # 01 - Carga y limpieza de datos
#
# En este notebook cargo los JSON de PyCEFR y Radon y los dejo en dos tablas principales:
#
# - `pycefr_constructs_global.csv`: constructos detectados por PyCEFR.
# - `radon_functions_global.csv`: funciones detectadas por Radon.
#
# Con esto ya puedo trabajar después con pandas sin pelearme con cada JSON por separado.

# %%
from pathlib import Path
import json
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

BASE_DIR = Path("..").resolve()
DATA_DIR = BASE_DIR / "data"
PROCESSED_DIR = DATA_DIR / "processed"
OUTPUT_DIR = BASE_DIR / "outputs"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

LEVEL_ORDER = {"A1": 1, "A2": 2, "B1": 3, "B2": 4, "C1": 5, "C2": 6}
LEVEL_ORDER_INV = {v: k for k, v in LEVEL_ORDER.items()}
RADON_GRADE_ORDER = {"A": 1, "B": 2, "C": 3, "D": 4, "E": 5, "F": 6}
RADON_GRADE_ORDER_INV = {v: k for k, v in RADON_GRADE_ORDER.items()}

def clean_file_name(path):
    """Devuelve un nombre de fichero comparable entre herramientas."""
    return Path(str(path)).name

def load_json(path):
    with open(path, "r", encoding="utf-8") as f:
        return json.load(f)

def detect_json_type(path):
    """Intenta detectar si un JSON parece de Radon o de PyCEFR."""
    try:
        data = load_json(path)
    except Exception:
        return "unknown"
    # Buscar un registro de ejemplo dentro del árbol project/file/[records]
    for project, files in data.items():
        if not isinstance(files, dict):
            continue
        for file_path, records in files.items():
            if isinstance(records, list) and records:
                rec = records[0]
                if isinstance(rec, dict):
                    if {"Class", "Start Line", "End Line", "Level"}.issubset(set(rec.keys())):
                        return "pycefr"
                    if {"type", "rank", "complexity", "lineno", "endline"}.issubset(set(rec.keys())):
                        return "radon"
    return "unknown"


def normalize_pycefr_json(data, source_file=None, case_name=None):
    rows = []
    for project, files in data.items():
        if not isinstance(files, dict):
            continue
        for file_path, records in files.items():
            if not isinstance(records, list):
                continue
            for rec in records:
                if not isinstance(rec, dict):
                    continue
                level = rec.get("Level")
                rows.append({
                    "case": case_name,
                    "project": project,
                    "file": str(file_path),
                    "file_name": clean_file_name(file_path),
                    "class": rec.get("Class"),
                    "start_line": pd.to_numeric(rec.get("Start Line"), errors="coerce"),
                    "end_line": pd.to_numeric(rec.get("End Line"), errors="coerce"),
                    "displacement": pd.to_numeric(rec.get("Displacement"), errors="coerce"),
                    "level": level,
                    "level_num": LEVEL_ORDER.get(level),
                    "source_file": str(source_file) if source_file else None,
                })
    return pd.DataFrame(rows)

def normalize_radon_json(data, source_file=None, case_name=None, include_closures=True):
    rows = []
    def add_rec(project, file_path, rec, parent=None, depth=0):
        if not isinstance(rec, dict):
            return
        radon_grade = rec.get("rank")
        rows.append({
            "case": case_name,
            "project": project,
            "file": str(file_path),
            "file_name": clean_file_name(file_path),
            "type": rec.get("type"),
            "name": rec.get("name"),
            "complexity": pd.to_numeric(rec.get("complexity"), errors="coerce"),
            "radon_grade": radon_grade,
            "radon_grade_num": RADON_GRADE_ORDER.get(radon_grade),
            "lineno": pd.to_numeric(rec.get("lineno"), errors="coerce"),
            "endline": pd.to_numeric(rec.get("endline"), errors="coerce"),
            "col_offset": pd.to_numeric(rec.get("col_offset"), errors="coerce"),
            "parent": parent,
            "closure_depth": depth,
            "source_file": str(source_file) if source_file else None,
        })
        if include_closures:
            for child in rec.get("closures", []) or []:
                add_rec(project, file_path, child, parent=rec.get("name"), depth=depth+1)
    for project, files in data.items():
        if not isinstance(files, dict):
            continue
        for file_path, records in files.items():
            if not isinstance(records, list):
                continue
            for rec in records:
                add_rec(project, file_path, rec)
    return pd.DataFrame(rows)

def find_case_folders(processed_dir=PROCESSED_DIR):
    if not processed_dir.exists():
        return []
    return sorted([p for p in processed_dir.iterdir() if p.is_dir()])

def load_all_processed():
    pycefr_parts = []
    radon_parts = []
    catalog_rows = []
    for case_dir in find_case_folders():
        for path in sorted(case_dir.rglob("*.json")):
            file_type = detect_json_type(path)
            catalog_rows.append({"case": case_dir.name, "path": str(path), "type": file_type})
            if file_type == "pycefr":
                pycefr_parts.append(normalize_pycefr_json(load_json(path), path, case_dir.name))
            elif file_type == "radon":
                radon_parts.append(normalize_radon_json(load_json(path), path, case_dir.name))
    pycefr = pd.concat(pycefr_parts, ignore_index=True) if pycefr_parts else pd.DataFrame()
    radon = pd.concat(radon_parts, ignore_index=True) if radon_parts else pd.DataFrame()
    catalog = pd.DataFrame(catalog_rows)
    return catalog, pycefr, radon

# %%
catalog, df_pycefr, df_radon = load_all_processed()

print("Catálogo:", catalog.shape)
print("PyCEFR:", df_pycefr.shape)
print("Radon:", df_radon.shape)
# Out:
# Catálogo: (10, 3)
# PyCEFR: (35647, 11)
# Radon: (1961, 15)

# %%
# vemos ejemplos de los datos en cada tabla que hemos creado 
display(catalog.head())
display(df_pycefr.head())
display(df_radon.head())
# Out:
#                  case                                               path  \
# 0   30-Days-Of-Python  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 1   30-Days-Of-Python  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 2  Analisis-CC-PyCEFR  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 3  Analisis-CC-PyCEFR  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 4   python-algorithms  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
#
#      type
# 0  pycefr
# 1   radon
# 2  pycefr
# 3   radon
# 4  pycefr
#                 case                             project          file  \
# 0  30-Days-Of-Python  02_Day_Variables_builtin_functions  variables.py
# 1  30-Days-Of-Python  02_Day_Variables_builtin_functions  variables.py
# 2  30-Days-Of-Python  02_Day_Variables_builtin_functions  variables.py
# 3  30-Days-Of-Python  02_Day_Variables_builtin_functions  variables.py
# 4  30-Days-Of-Python  02_Day_Variables_builtin_functions  variables.py
#
#       file_name              class  start_line  end_line  displacement level  \
# 0  variables.py        Simple List          10        10             9    A1
# 1  variables.py       Simple Tuple          33        33             0    A1
# 2  variables.py       Simple Tuple          33        33            50    A1
# 3  variables.py  Simple Dictionary          11        16            14    A2
# 4  variables.py              Print          20        20             0    A1
#
#    level_num                                        source_file
# 0          1  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 1          1  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 2          1  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 3          2  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 4          1  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
#                 case            project  \
# 0  30-Days-Of-Python  30-Days-Of-Python
# 1  30-Days-Of-Python  30-Days-Of-Python
# 2  30-Days-Of-Python  30-Days-Of-Python
# 3  30-Days-Of-Python  30-Days-Of-Python
# 4  30-Days-Of-Python  30-Days-Of-Python
#
#                                                 file      file_name      type  \
# 0  /home/juan/Documents/Analisis-CC-PyCEFR/30-Day...    mymodule.py  function
# 1  /home/juan/Documents/Analisis-CC-PyCEFR/30-Day...    mymodule.py  function
# 2  /home/juan/Documents/Analisis-CC-PyCEFR/30-Day...    mymodule.py  function
# 3  /home/juan/Documents/Analisis-CC-PyCEFR/30-Day...    mymodule.py  function
# 4  /home/juan/Documents/Analisis-CC-PyCEFR/30-Day...  arithmetic.py  function
#
#                  name  complexity radon_grade  radon_grade_num  lineno  \
# 0  generate_full_name           1           A                1       1
# 1        sum_two_nums           1           A                1       7
# 2  generate_full_name           1           A                1       1
# 3        sum_two_nums           1           A                1       6
# 4         add_numbers           2           A                1       1
#
#    endline  col_offset parent  closure_depth  \
# 0        4           0   None              0
# 1        8           0   None              0
# 2        4           0   None              0
# 3        7           0   None              0
# 4        5           0   None              0
#
#                                          source_file
# 0  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 1  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 2  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 3  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 4  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...

# %%
df_pycefr.to_csv(OUTPUT_DIR / "pycefr_constructs_global.csv", index=False)
df_radon.to_csv(OUTPUT_DIR / "radon_functions_global.csv", index=False)
print("Archivos guardados en", OUTPUT_DIR)
# Out:
# Archivos guardados en /home/juan/Documents/Analisis-CC-PyCEFR/outputs
