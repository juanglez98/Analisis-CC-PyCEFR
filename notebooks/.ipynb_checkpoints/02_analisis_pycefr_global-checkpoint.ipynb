# %% [markdown]
# # 02 - Análisis general de PyCEFR
#
# Aquí se analiza qué niveles y constructos detecta la herramienta basada en PyCEFR en todo el conjunto de proyectos.

# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt

BASE_DIR = Path("..").resolve()
OUTPUT_DIR = BASE_DIR / "outputs"
FIGURES_DIR = OUTPUT_DIR / "figures"
FIGURES_DIR.mkdir(parents=True, exist_ok=True)

df_pycefr = pd.read_csv(OUTPUT_DIR / "pycefr_constructs_global.csv")
df_pycefr.head()
# Out:
#                 case                             project          file  \
# 0  30-Days-Of-Python  02_Day_Variables_builtin_functions  variables.py
# 1  30-Days-Of-Python  02_Day_Variables_builtin_functions  variables.py
# 2  30-Days-Of-Python  02_Day_Variables_builtin_functions  variables.py
# 3  30-Days-Of-Python  02_Day_Variables_builtin_functions  variables.py
# 4  30-Days-Of-Python  02_Day_Variables_builtin_functions  variables.py
#
#       file_name              class  start_line  end_line  displacement level  \
# 0  variables.py        Simple List          10        10             9    A1
# 1  variables.py       Simple Tuple          33        33             0    A1
# 2  variables.py       Simple Tuple          33        33            50    A1
# 3  variables.py  Simple Dictionary          11        16            14    A2
# 4  variables.py              Print          20        20             0    A1
#
#    level_num                                        source_file
# 0          1  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 1          1  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 2          1  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 3          2  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 4          1  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...

# %%
level_counts = df_pycefr["level"].value_counts().reindex(LEVEL_ORDER.keys(), fill_value=0)
level_counts
# Out:
# level
# A1    22102
# A2    11427
# B1     1526
# B2      326
# C1      181
# C2       85
# Name: count, dtype: int64

# %%
plt.figure(figsize=(7,4))
level_counts.plot.bar()
plt.title("Distribución general de niveles PyCEFR")
plt.xlabel("Nivel")
plt.ylabel("Número de constructos")
plt.tight_layout()
plt.savefig(OUTPUT_DIR / "02_pycefr_distribucion_niveles.png", dpi=150)
plt.show()

# %%
top_classes = df_pycefr["class"].value_counts().head(20)
top_classes
# Out:
# class
# Simple Atributte                                          9385
# Simple Assignment                                         6338
# Subscript                                                 2198
# Print                                                     1934
# Simple List                                               1862
# Simple If statements                                      1804
# Simple Tuple                                              1667
# Return                                                    1582
# Function with Simple argument                             1119
# Alias                                                      840
# Unary Operation                                            657
# Assigment with sum (total = total + 1)                     464
# Simple For Loop                                            458
# Boolean Operation                                          417
# While with Else Loop                                       414
# Import                                                     348
# 'range' call function                                      316
# Simplified incremental Assignment with increase amount     304
# From                                                       270
# 1 List Dictionary                                          251
# Name: count, dtype: int64

# %%
plt.figure(figsize=(9,6))
top_classes.sort_values().plot.barh()
plt.title("Constructos PyCEFR más frecuentes")
plt.xlabel("Frecuencia")
plt.ylabel("Constructo")
plt.tight_layout()
plt.savefig(OUTPUT_DIR / "02_pycefr_top_constructos.png", dpi=150)
plt.show()

# %%
pycefr_by_case = (
    df_pycefr.groupby("case")
    .agg(
        n_constructs=("class", "count"),
        n_classes=("class", "nunique"),
        max_level_num=("level_num", "max"),
        mean_level_num=("level_num", "mean"),
        max_displacement=("displacement", "max"),
    )
    .reset_index()
)
pycefr_by_case["max_level"] = pycefr_by_case["max_level_num"].map(LEVEL_ORDER_INV)
pycefr_by_case.sort_values(["max_level_num", "n_constructs"], ascending=False)
# Out:
#                                     case  n_constructs  n_classes  \
# 2                      python-algorithms         21724         57
# 4                   python-mini-projects         10907         83
# 3  python-beginner-programming-exercises          1176         32
# 1                     Analisis-CC-PyCEFR           482         39
# 0                      30-Days-Of-Python          1358         29
#
#    max_level_num  mean_level_num  max_displacement max_level
# 2              6        1.411803               313        C2
# 4              6        1.547813               170        C2
# 3              5        1.780612               531        C1
# 1              5        1.344398               103        C1
# 0              4        1.442563                89        B2

# %%
pycefr_high = df_pycefr[df_pycefr["level_num"] >= 4].sort_values(["level_num", "case", "file_name"], ascending=[False, True, True])
pycefr_high.head(50)
# Out:
#                     case                                            project  \
# 16898  python-algorithms                                           avl-tree
# 18109  python-algorithms                                               heap
# 17277  python-algorithms                                 binary-search-tree
# 17552  python-algorithms                              binary-tree-with-list
# 13459  python-algorithms                              2_ceiling_of_a_number
# 18282  python-algorithms                        circular-doubly-linked-list
# 18283  python-algorithms                        circular-doubly-linked-list
# 18501  python-algorithms                               circular-linked-list
# 18502  python-algorithms                               circular-linked-list
# 20322  python-algorithms               6_closest_entries_in_3_sorted_arrays
# 5408   python-algorithms  lc_106_construct_binary_tree_from_inorder_post...
# 3793   python-algorithms  lc_105_construct_binary_tree_from_preorder_ino...
# 3822   python-algorithms  lc_105_construct_binary_tree_from_preorder_ino...
# 19125  python-algorithms                                 doubly-linked-list
# 19126  python-algorithms                                 doubly-linked-list
# 7398   python-algorithms                           lc_399_evaluate_division
# 11885  python-algorithms                 k_smallest_number_in_m_sorted_list
# 11639  python-algorithms                            median_in_sorted_arrays
# 11746  python-algorithms                              merge_k_sorted_arrays
# 19854  python-algorithms                              1_merge_sorted_arrays
# 12905  python-algorithms                               pair_with_target_sum
# 8859   python-algorithms                            lc_336_palindrome_pairs
# 8860   python-algorithms                            lc_336_palindrome_pairs
# 16536  python-algorithms                              queue_with_linkedlist
# 16537  python-algorithms                              queue_with_linkedlist
# 16538  python-algorithms                              queue_with_linkedlist
# 16696  python-algorithms                                     circular_queue
# 16836  python-algorithms                                    queue_with_list
# 16837  python-algorithms                                    queue_with_list
# 17152  python-algorithms                                           avl-tree
# 17153  python-algorithms                                           avl-tree
# 17154  python-algorithms                                           avl-tree
# 17427  python-algorithms                                 binary-search-tree
# 17428  python-algorithms                                 binary-search-tree
# 17429  python-algorithms                                 binary-search-tree
# 18002  python-algorithms                        binary-tree-with-linkedlist
# 18003  python-algorithms                        binary-tree-with-linkedlist
# 18004  python-algorithms                        binary-tree-with-linkedlist
# 22536  python-algorithms  12_reconstruct_binary_tree_from_preorder_inord...
# 8992   python-algorithms                               lc_648_replace_words
# 8993   python-algorithms                               lc_648_replace_words
# 11698  python-algorithms                              smallest_number_range
# 19887  python-algorithms                 2_sort_increasing_decreasing_array
# 19048  python-algorithms                                              stack
# 18937  python-algorithms                                              stack
# 18938  python-algorithms                                              stack
# 18939  python-algorithms                                              stack
# 18880  python-algorithms                                              stack
# 3083   python-algorithms                                            two_sum
# 8643   python-algorithms                                lc_139_word_break_I
#
#                                                     file  \
# 16898                                        avl_tree.py
# 18109                                     binary_heap.py
# 17277                              binary_search_tree.py
# 17552                                     binary_tree.py
# 13459                               ceiling_of_number.py
# 18282                     circular_doubly_linked_list.py
# 18283                     circular_doubly_linked_list.py
# 18501                            circular_linked_list.py
# 18502                            circular_linked_list.py
# 20322                                   close_entries.py
# 5408   construct_binary_tree_from_inorder_postorder_t...
# 3793   construct_binary_tree_from_preorder_inorder_tr...
# 3822   construct_binary_tree_from_preorder_inorder_tr...
# 19125                              doubly_linked_list.py
# 19126                              doubly_linked_list.py
# 7398                                evaluate_division.py
# 11885                               k_smallest_number.py
# 11639                         median_in_sorted_arrays.py
# 11746                           merge_k_sorted_arrays.py
# 19854                             merge_sorted_arrays.py
# 12905                            pair_with_target_sum.py
# 8859                                 palindrome_pairs.py
# 8860                                 palindrome_pairs.py
# 16536                                           queue.py
# 16537                                           queue.py
# 16538                                           queue.py
# 16696                                           queue.py
# 16836                                           queue.py
# 16837                                           queue.py
# 17152                                           queue.py
# 17153                                           queue.py
# 17154                                           queue.py
# 17427                                           queue.py
# 17428                                           queue.py
# 17429                                           queue.py
# 18002                                           queue.py
# 18003                                           queue.py
# 18004                                           queue.py
# 22536                                  reconstruct_bt.py
# 8992                                    replace_words.py
# 8993                                    replace_words.py
# 11698                           smallest_number_range.py
# 19887                            sort_k_inc_dec_array.py
# 19048                         stack_with_limited_list.py
# 18937                           stack_with_linkedlist.py
# 18938                           stack_with_linkedlist.py
# 18939                           stack_with_linkedlist.py
# 18880                                 stack_with_list.py
# 3083                                          two_sum.py
# 8643                                       word_break.py
#
#                                                file_name  \
# 16898                                        avl_tree.py
# 18109                                     binary_heap.py
# 17277                              binary_search_tree.py
# 17552                                     binary_tree.py
# 13459                               ceiling_of_number.py
# 18282                     circular_doubly_linked_list.py
# 18283                     circular_doubly_linked_list.py
# 18501                            circular_linked_list.py
# 18502                            circular_linked_list.py
# 20322                                   close_entries.py
# 5408   construct_binary_tree_from_inorder_postorder_t...
# 3793   construct_binary_tree_from_preorder_inorder_tr...
# 3822   construct_binary_tree_from_preorder_inorder_tr...
# 19125                              doubly_linked_list.py
# 19126                              doubly_linked_list.py
# 7398                                evaluate_division.py
# 11885                               k_smallest_number.py
# 11639                         median_in_sorted_arrays.py
# 11746                           merge_k_sorted_arrays.py
# 19854                             merge_sorted_arrays.py
# 12905                            pair_with_target_sum.py
# 8859                                 palindrome_pairs.py
# 8860                                 palindrome_pairs.py
# 16536                                           queue.py
# 16537                                           queue.py
# 16538                                           queue.py
# 16696                                           queue.py
# 16836                                           queue.py
# 16837                                           queue.py
# 17152                                           queue.py
# 17153                                           queue.py
# 17154                                           queue.py
# 17427                                           queue.py
# 17428                                           queue.py
# 17429                                           queue.py
# 18002                                           queue.py
# 18003                                           queue.py
# 18004                                           queue.py
# 22536                                  reconstruct_bt.py
# 8992                                    replace_words.py
# 8993                                    replace_words.py
# 11698                           smallest_number_range.py
# 19887                            sort_k_inc_dec_array.py
# 19048                         stack_with_limited_list.py
# 18937                           stack_with_linkedlist.py
# 18938                           stack_with_linkedlist.py
# 18939                           stack_with_linkedlist.py
# 18880                                 stack_with_list.py
# 3083                                          two_sum.py
# 8643                                       word_break.py
#
#                            class  start_line  end_line  displacement level  \
# 16898             Super Function           5         5             8    C2
# 18109             Super Function          10        10             8    C2
# 17277             Super Function           5         5             8    C2
# 17552             Super Function           5         5             8    C2
# 13459  'enumerate' call function          37        37            20    C2
# 18282             Super Function           3         3             8    C2
# 18283             Super Function          29        29             8    C2
# 18501             Super Function           3         3             8    C2
# 18502             Super Function          18        18             8    C2
# 20322  'enumerate' call function           7         7            29    C2
# 5408   'enumerate' call function           8         8            54    C2
# 3793   'enumerate' call function           7         7            49    C2
# 3822   'enumerate' call function           8         8            54    C2
# 19125             Super Function           4         4             8    C2
# 19126             Super Function          28        28             8    C2
# 7398   'enumerate' call function          23        23            23    C2
# 11885  'enumerate' call function          20        20            15    C2
# 11639  'enumerate' call function          18        18            16    C2
# 11746  'enumerate' call function          18        18            16    C2
# 19854  'enumerate' call function          44        44            22    C2
# 12905  'enumerate' call function          39        39            18    C2
# 8859   'enumerate' call function          50        50            19    C2
# 8860   'enumerate' call function          54        54            19    C2
# 16536             Super Function           5         5             8    C2
# 16537             Super Function          14        14             8    C2
# 16538             Super Function          29        29             8    C2
# 16696             Super Function           3         3             8    C2
# 16836             Super Function           4         4             8    C2
# 16837             Super Function           8         8             8    C2
# 17152             Super Function           5         5             8    C2
# 17153             Super Function          14        14             8    C2
# 17154             Super Function          29        29             8    C2
# 17427             Super Function           5         5             8    C2
# 17428             Super Function          14        14             8    C2
# 17429             Super Function          29        29             8    C2
# 18002             Super Function           5         5             8    C2
# 18003             Super Function          14        14             8    C2
# 18004             Super Function          29        29             8    C2
# 22536  'enumerate' call function          15        15            50    C2
# 8992   'enumerate' call function          34        34            21    C2
# 8993   'enumerate' call function          19        19            25    C2
# 11698  'enumerate' call function          20        20            16    C2
# 19887  'enumerate' call function          44        44            29    C2
# 19048             Super Function           5         5             8    C2
# 18937             Super Function           4         4             8    C2
# 18938             Super Function          20        20             8    C2
# 18939             Super Function          35        35             8    C2
# 18880             Super Function           5         5             8    C2
# 3083   'enumerate' call function           4         4            18    C2
# 8643   'enumerate' call function          20        20            23    C2
#
#        level_num                                        source_file
# 16898          6  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 18109          6  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 17277          6  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 17552          6  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 13459          6  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 18282          6  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 18283          6  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 18501          6  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 18502          6  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 20322          6  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 5408           6  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 3793           6  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 3822           6  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 19125          6  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 19126          6  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 7398           6  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 11885          6  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 11639          6  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 11746          6  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 19854          6  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 12905          6  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 8859           6  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 8860           6  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 16536          6  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 16537          6  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 16538          6  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 16696          6  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 16836          6  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 16837          6  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 17152          6  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 17153          6  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 17154          6  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 17427          6  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 17428          6  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 17429          6  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 18002          6  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 18003          6  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 18004          6  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 22536          6  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 8992           6  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 8993           6  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 11698          6  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 19887          6  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 19048          6  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 18937          6  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 18938          6  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 18939          6  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 18880          6  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 3083           6  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 8643           6  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...

# %%
pycefr_by_case.to_csv(OUTPUT_DIR / "02_pycefr_resumen_por_caso.csv", index=False)
pycefr_high.to_csv(OUTPUT_DIR / "02_pycefr_constructos_alto_nivel.csv", index=False)
