# %% [markdown]
# # 03 - Análisis general de Radon
#
# Este notebook analiza las funciones detectadas por Radon, sus calificaciones y su complejidad ciclomática.

# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt

BASE_DIR = Path("..").resolve()
OUTPUT_DIR = BASE_DIR / "outputs"
FIGURES_DIR = OUTPUT_DIR / "figures"
FIGURES_DIR.mkdir(parents=True, exist_ok=True)

df_radon = pd.read_csv(OUTPUT_DIR / "radon_functions_global.csv")
df_radon.head()

# Compatibilidad por si existe una tabla antigua con la columna "rank"
if "radon_grade" not in df_radon.columns and "rank" in df_radon.columns:
    df_radon["radon_grade"] = df_radon["rank"]
if "radon_grade_num" not in df_radon.columns and "rank_num" in df_radon.columns:
    df_radon["radon_grade_num"] = df_radon["rank_num"]

# %%
grade_counts = df_radon["radon_grade"].value_counts().reindex(RADON_GRADE_ORDER.keys(), fill_value=0)
grade_counts
# Out:
# radon_grade
# A    1721
# B     211
# C      25
# D       2
# E       2
# F       0
# Name: count, dtype: int64

# %%
plt.figure(figsize=(7,4))
grade_counts.plot.bar()
plt.title("Distribución general de calificaciones de Radon")
plt.xlabel("Calificación")
plt.ylabel("Número de funciones")
plt.tight_layout()
plt.savefig(OUTPUT_DIR / "03_radon_distribucion_calificaciones.png", dpi=150)
plt.show()

# %%
plt.figure(figsize=(7,4))
df_radon["complexity"].dropna().plot.hist(bins=20)
plt.title("Histograma de complejidad ciclomática")
plt.xlabel("Complejidad")
plt.ylabel("Número de funciones")
plt.tight_layout()
plt.savefig(OUTPUT_DIR / "03_radon_hist_complejidad.png", dpi=150)
plt.show()

# %%
radon_by_case = (
    df_radon.groupby("case")
    .agg(
        n_functions=("name", "count"),
        max_complexity=("complexity", "max"),
        mean_complexity=("complexity", "mean"),
        max_radon_grade_num=("radon_grade_num", "max"),
        n_closures=("parent", lambda s: s.notna().sum()),
    )
    .reset_index()
)
radon_by_case["max_radon_grade"] = radon_by_case["max_radon_grade_num"].map(RADON_GRADE_ORDER_INV)
radon_by_case.sort_values(["max_radon_grade_num", "max_complexity"], ascending=False)
# Out:
#                                     case  n_functions  max_complexity  \
# 4                   python-mini-projects          340              34
# 2                      python-algorithms         1474              16
# 1                     Analisis-CC-PyCEFR           16              10
# 3  python-beginner-programming-exercises          109               8
# 0                      30-Days-Of-Python           22               3
#
#    mean_complexity  max_radon_grade_num  n_closures max_radon_grade
# 4         3.020588                    5           4               E
# 2         2.957938                    3         119               C
# 1         4.937500                    2           1               B
# 3         2.165138                    2           0               B
# 0         1.181818                    1           0               A

# %%
radon_top = df_radon.sort_values("complexity", ascending=False).head(50)
radon_top
# Out:
#                       case               project  \
# 1824  python-mini-projects  python-mini-projects
# 1638  python-mini-projects  python-mini-projects
# 1876  python-mini-projects  python-mini-projects
# 1713  python-mini-projects  python-mini-projects
# 1946  python-mini-projects  python-mini-projects
# 1850  python-mini-projects  python-mini-projects
# 1647  python-mini-projects  python-mini-projects
# 1278     python-algorithms     python-algorithms
# 983      python-algorithms     python-algorithms
# 1714  python-mini-projects  python-mini-projects
# 620      python-algorithms     python-algorithms
# 1934  python-mini-projects  python-mini-projects
# 395      python-algorithms     python-algorithms
# 1950  python-mini-projects  python-mini-projects
# 695      python-algorithms     python-algorithms
# 1940  python-mini-projects  python-mini-projects
# 618      python-algorithms     python-algorithms
# 1856  python-mini-projects  python-mini-projects
# 624      python-algorithms     python-algorithms
# 426      python-algorithms     python-algorithms
# 984      python-algorithms     python-algorithms
# 628      python-algorithms     python-algorithms
# 622      python-algorithms     python-algorithms
# 200      python-algorithms     python-algorithms
# 199      python-algorithms     python-algorithms
# 414      python-algorithms     python-algorithms
# 1929  python-mini-projects  python-mini-projects
# 58       python-algorithms     python-algorithms
# 1092     python-algorithms     python-algorithms
# 359      python-algorithms     python-algorithms
# 630      python-algorithms     python-algorithms
# 421      python-algorithms     python-algorithms
# 51       python-algorithms     python-algorithms
# 1733  python-mini-projects  python-mini-projects
# 1434     python-algorithms     python-algorithms
# 1930  python-mini-projects  python-mini-projects
# 797      python-algorithms     python-algorithms
# 26      Analisis-CC-PyCEFR    Analisis-CC-PyCEFR
# 25      Analisis-CC-PyCEFR    Analisis-CC-PyCEFR
# 24      Analisis-CC-PyCEFR    Analisis-CC-PyCEFR
# 626      python-algorithms     python-algorithms
# 920      python-algorithms     python-algorithms
# 928      python-algorithms     python-algorithms
# 919      python-algorithms     python-algorithms
# 908      python-algorithms     python-algorithms
# 784      python-algorithms     python-algorithms
# 761      python-algorithms     python-algorithms
# 834      python-algorithms     python-algorithms
# 1457     python-algorithms     python-algorithms
# 1622  python-mini-projects  python-mini-projects
#
#                                                    file  \
# 1824  /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 1638  /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 1876  /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 1713  /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 1946  /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 1850  /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 1647  /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 1278  /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 983   /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 1714  /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 620   /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 1934  /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 395   /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 1950  /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 695   /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 1940  /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 618   /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 1856  /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 624   /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 426   /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 984   /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 628   /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 622   /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 200   /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 199   /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 414   /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 1929  /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 58    /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 1092  /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 359   /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 630   /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 421   /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 51    /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 1733  /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 1434  /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 1930  /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 797   /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 26    /home/juan/Documents/Analisis-CC-PyCEFR/Analis...
# 25    /home/juan/Documents/Analisis-CC-PyCEFR/Analis...
# 24    /home/juan/Documents/Analisis-CC-PyCEFR/Analis...
# 626   /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 920   /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 928   /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 919   /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 908   /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 784   /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 761   /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 834   /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 1457  /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 1622  /home/juan/Documents/Analisis-CC-PyCEFR/python...
#
#                              file_name      type  \
# 1824                            bot.py    method
# 1638                      converter.py  function
# 1876                  biling_system.py    method
# 1713                 tic-tac-toe-AI.py  function
# 1946                           main.py  function
# 1850                        hangman.py  function
# 1647       Rock-Paper-Scissors Game.py  function
# 1278                 is_bst_ordered.py  function
# 983                        avl_tree.py  function
# 1714                 tic-tac-toe-AI.py  function
# 620                alien_dictionary.py  function
# 1934                          utils.py  function
# 395          merge_two_binary_trees.py  function
# 1950                     profilepic.py  function
# 695         median_in_sorted_arrays.py  function
# 1940                   store_emails.py  function
# 618           task_scheduling_order.py  function
# 1856               movieInfoScraper.py  function
# 624         course_scheduling_order.py  function
# 426                detect_cycle_bfs.py  function
# 984                        avl_tree.py  function
# 628                topological_sort.py  function
# 622                      find_cycle.py  function
# 200                 delete_bst_node.py  function
# 199                 delete_bst_node.py  function
# 414            minimum_height_trees.py  function
# 1929                          model.py     class
# 58         floyd_warshall_algorithm.py  function
# 1092                    binary_heap.py    method
# 359        vertical_order_traversal.py  function
# 630                 task_scheduling.py  function
# 421             bfs_khans_algorithm.py  function
# 51             topological_sort_bfs.py  function
# 1733                          alarm.py  function
# 1434                            lca.py  function
# 1930                          model.py    method
# 797         search_in_rotated_array.py  function
# 26                        generator.py  function
# 25                        generator.py  function
# 24                        generator.py  function
# 626               course_scheduling.py  function
# 920                  string_anagram.py  function
# 928    reverse_alternate_k_elements.py  function
# 919                  find_substring.py  function
# 908                find_permutation.py  function
# 784   find_first_k_missing_positive.py  function
# 761          shortest_window_sort_2.py  function
# 834           palindrome_linkedlist.py  function
# 1457        remove_kth_last_element.py  function
# 1622                     snake_game.py  function
#
#                                name  complexity radon_grade  radon_grade_num  \
# 1824                     on_message          34           E                5
# 1638                      converter          34           E                5
# 1876                      bill_area          27           D                4
# 1713                      win_check          24           D                4
# 1946                          fetch          17           C                3
# 1850                           play          16           C                3
# 1647                           spin          16           C                3
# 1278                 is_bst_ordered          16           C                3
# 983                      deleteNode          14           C                3
# 1714                         CompAI          14           C                3
# 620                      find_order          13           C                3
# 1934                  build_dataset          13           C                3
# 395                mergeTreesHelper          13           C                3
# 1950                    pp_download          13           C                3
# 695                    merge_arrays          12           C                3
# 1940                   write_to_csv          12           C                3
# 618                      find_order          11           C                3
# 1856                getMovieDetails          11           C                3
# 624                      find_order          11           C                3
# 426                        is_cycle          11           C                3
# 984                      insertNode          11           C                3
# 628                topological_sort          11           C                3
# 622                topological_sort          11           C                3
# 200                   delete_node_2          11           C                3
# 199                     delete_node          11           C                3
# 414              findMinHeightTrees          11           C                3
# 1929                          Model          11           C                3
# 58                   floyd_warshall          11           C                3
# 1092                 heapifyExtract          11           C                3
# 359               verticalTraversal          10           B                2
# 630          is_scheduling_possible          10           B                2
# 421                        top_sort          10           B                2
# 51                 topological_sort          10           B                2
# 1733                      set_alarm          10           B                2
# 1434                            lca          10           B                2
# 1930                       __init__          10           B                2
# 797            search_rotated_array          10           B                2
# 26                     print_report          10           B                2
# 25                             walk          10           B                2
# 24                  extract_records          10           B                2
# 626          is_scheduling_possible          10           B                2
# 920            find_string_anagrams          10           B                2
# 928                       alternate          10           B                2
# 919                  find_substring          10           B                2
# 908                find_permutation          10           B                2
# 784   find_first_k_missing_positive          10           B                2
# 761            findUnsortedSubarray          10           B                2
# 834      is_palindromic_linked_list          10           B                2
# 1457         delete_kth_last_node_2           9           B                2
# 1622               change_direction           9           B                2
#
#       lineno  endline  col_offset           parent  closure_depth  \
# 1824      41      171           4              NaN              0
# 1638      19       72           0              NaN              0
# 1876     288      345           4              NaN              0
# 1713     154      168           0              NaN              0
# 1946      15       82           0              NaN              0
# 1850      16      101           0              NaN              0
# 1647      23       58           0              NaN              0
# 1278      25       51           0              NaN              0
# 983      190      222           0              NaN              0
# 1714      95      124           0              NaN              0
# 620       18       59           0              NaN              0
# 1934      59       80           0              NaN              0
# 395        9       23           4      merge_trees              1
# 1950       8       59           0              NaN              0
# 695       13       48           0              NaN              0
# 1940      44       96           0              NaN              0
# 618       12       46           0              NaN              0
# 1856       7       82           0              NaN              0
# 624       12       46           0              NaN              0
# 426        6       29           0              NaN              0
# 984      158      183           0              NaN              0
# 628       13       48           0              NaN              0
# 622       13       47           0              NaN              0
# 200       32       53           0              NaN              0
# 199        5       26           0              NaN              0
# 414        2       35           0              NaN              0
# 1929       6      131           0              NaN              0
# 58         2       20           0              NaN              0
# 1092      70      101           4              NaN              0
# 359       46       79           0              NaN              0
# 630       14       48           0              NaN              0
# 421        3       25           0              NaN              0
# 51        13       45           0              NaN              0
# 1733      18       66           0              NaN              0
# 1434       6       37           0              NaN              0
# 1930       7      131           4              NaN              0
# 797        8       30           0              NaN              0
# 26       328      370           0              NaN              0
# 25       228      245           4  extract_records              1
# 24       206      248           0              NaN              0
# 626       14       48           0              NaN              0
# 920        1       35           0              NaN              0
# 928       58       83           0              NaN              0
# 919        1       33           0              NaN              0
# 908        1       32           0              NaN              0
# 784        7       33           0              NaN              0
# 761        1       21           0              NaN              0
# 834       12       37           0              NaN              0
# 1457      23       40           0              NaN              0
# 1622      87      102           0              NaN              0
#
#                                             source_file
# 1824  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 1638  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 1876  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 1713  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 1946  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 1850  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 1647  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 1278  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 983   /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 1714  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 620   /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 1934  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 395   /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 1950  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 695   /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 1940  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 618   /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 1856  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 624   /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 426   /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 984   /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 628   /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 622   /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 200   /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 199   /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 414   /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 1929  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 58    /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 1092  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 359   /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 630   /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 421   /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 51    /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 1733  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 1434  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 1930  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 797   /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 26    /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 25    /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 24    /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 626   /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 920   /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 928   /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 919   /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 908   /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 784   /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 761   /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 834   /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 1457  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...
# 1622  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...

# %%
radon_by_case.to_csv(OUTPUT_DIR / "03_radon_resumen_por_caso.csv", index=False)
radon_top.to_csv(OUTPUT_DIR / "03_radon_funciones_mas_complejas.csv", index=False)
