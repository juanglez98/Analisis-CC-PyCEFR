# %% [markdown]
# # 03 - Análisis global de Radon
#
# Este notebook analiza las funciones detectadas por Radon, sus rangos y su complejidad ciclomática.

# %%
from pathlib import Path
import json
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

BASE_DIR = Path("..").resolve()
DATA_DIR = BASE_DIR / "data"
PROCESSED_DIR = DATA_DIR / "processed"
OUTPUT_DIR = BASE_DIR / "outputs"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

LEVEL_ORDER = {"A1": 1, "A2": 2, "B1": 3, "B2": 4, "C1": 5, "C2": 6}
LEVEL_ORDER_INV = {v: k for k, v in LEVEL_ORDER.items()}
RADON_RANK_ORDER = {"A": 1, "B": 2, "C": 3, "D": 4, "E": 5, "F": 6}
RADON_RANK_ORDER_INV = {v: k for k, v in RADON_RANK_ORDER.items()}

def clean_file_name(path):
    """Devuelve un nombre de fichero comparable entre herramientas."""
    return Path(str(path)).name

def load_json(path):
    with open(path, "r", encoding="utf-8") as f:
        return json.load(f)

def detect_json_kind(path):
    """Intenta detectar si un JSON parece de Radon o de PyCEFR."""
    try:
        data = load_json(path)
    except Exception:
        return "unknown"
    # Buscar un registro de ejemplo dentro del árbol project/file/[records]
    for project, files in data.items():
        if not isinstance(files, dict):
            continue
        for file_path, records in files.items():
            if isinstance(records, list) and records:
                rec = records[0]
                if isinstance(rec, dict):
                    if {"Class", "Start Line", "End Line", "Level"}.issubset(set(rec.keys())):
                        return "pycefr"
                    if {"type", "rank", "complexity", "lineno", "endline"}.issubset(set(rec.keys())):
                        return "radon"
    return "unknown"

# %%
df_radon = pd.read_csv(OUTPUT_DIR / "radon_functions_global.csv")
df_radon.head()

# %%
rank_counts = df_radon["rank"].value_counts().reindex(RADON_RANK_ORDER.keys(), fill_value=0)
rank_counts

# %%
plt.figure(figsize=(7,4))
rank_counts.plot(kind="bar")
plt.title("Distribución global de ranks Radon")
plt.xlabel("Rank")
plt.ylabel("Número de funciones")
plt.tight_layout()
plt.savefig(OUTPUT_DIR / "03_radon_distribucion_ranks.png", dpi=150)
plt.show()

# %%
plt.figure(figsize=(7,4))
df_radon["complexity"].dropna().plot(kind="hist", bins=20)
plt.title("Histograma de complejidad ciclomática")
plt.xlabel("Complejidad")
plt.ylabel("Número de funciones")
plt.tight_layout()
plt.savefig(OUTPUT_DIR / "03_radon_hist_complejidad.png", dpi=150)
plt.show()

# %%
radon_by_case = (
    df_radon.groupby("case")
    .agg(
        n_functions=("name", "count"),
        max_complexity=("complexity", "max"),
        mean_complexity=("complexity", "mean"),
        max_rank_num=("rank_num", "max"),
        n_closures=("parent", lambda s: s.notna().sum()),
    )
    .reset_index()
)
radon_by_case["max_rank"] = radon_by_case["max_rank_num"].map(RADON_RANK_ORDER_INV)
radon_by_case.sort_values(["max_rank_num", "max_complexity"], ascending=False)

# %%
radon_top = df_radon.sort_values("complexity", ascending=False).head(50)
radon_top

# %%
radon_by_case.to_csv(OUTPUT_DIR / "03_radon_resumen_por_caso.csv", index=False)
radon_top.to_csv(OUTPUT_DIR / "03_radon_funciones_mas_complejas.csv", index=False)

# %% [markdown]
# ## Comentario para la memoria
#
# Radon ofrece una visión funcional de la complejidad: cada función recibe una complejidad ciclomática y un rango. Esto permite identificar funciones con muchos caminos de ejecución, normalmente provocados por condiciones, bucles, excepciones o combinaciones de estructuras de control.
