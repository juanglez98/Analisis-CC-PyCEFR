# %% [markdown]
# # 00 - Configuración y catálogo de datos
#
# Este notebook comprueba qué ficheros hay en `data/processed` y detecta si cada JSON pertenece a Radon o a PyCEFR.
#
# La idea es empezar sin asumir demasiado sobre los nombres de los archivos.

# %%
from pathlib import Path
import json
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

BASE_DIR = Path("..").resolve()
DATA_DIR = BASE_DIR / "data"
PROCESSED_DIR = DATA_DIR / "processed"
OUTPUT_DIR = BASE_DIR / "outputs"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

LEVELS_PYCEFR = {"A1": 1, "A2": 2, "B1": 3, "B2": 4, "C1": 5, "C2": 6}
LEVELS_PYCEFR_INV = {v: k for k, v in LEVELS_PYCEFR.items()}
RADON_LEVELS = {"A": 1, "B": 2, "C": 3, "D": 4, "E": 5, "F": 6}
RADON_LEVELS_INV = {v: k for k, v in RADON_LEVELS.items()}

def clean_file_name(path):
    """Devuelve un nombre de fichero comparable entre herramientas."""
    return Path(str(path)).name

def load_json(path):
    with open(path, "r", encoding="utf-8") as f:
        return json.load(f)


def detect_json_type(path):
    """
    Intenta saber si un JSON viene de Radon o de PyCEFR.
    """
    try:
        data = load_json(path)
    except Exception:
        return "unknown"

    for project, files in data.items():
        if not isinstance(files, dict):
            continue

        for file_path, records in files.items():
            if isinstance(records, list) and records:
                rec = records[0]

                if isinstance(rec, dict):
                    if {"Class", "Start Line", "End Line", "Level"}.issubset(set(rec.keys())):
                        return "pycefr"

                    if {"type", "rank", "complexity", "lineno", "endline"}.issubset(set(rec.keys())):
                        return "radon"

    return "unknown"


def detect_csv_type(path):
    
    name = path.name.lower()

    # Primero usamos el nombre como pista rápida
    if "radon" in name:
        return "radon_csv"

    if "pycefr" in name or name == "data.csv" or name == "data_pycefr.csv":
        possible_by_name = "pycefr_csv"
    else:
        possible_by_name = "csv_unknown"

    # Después intentamos leer columnas
    try:
        df_sample = pd.read_csv(path, nrows=5)
        columns = set(df_sample.columns)
    except Exception:
        return possible_by_name

    # Columnas típicas de PyCEFR
    pycefr_columns = {"Class", "Start Line", "End Line", "Displacement", "Level"}
    if pycefr_columns.intersection(columns):
        return "pycefr_csv"

    # Columnas típicas de Radon
    radon_columns = {"Repository", "File Name", "Type", "Name", "Line", "Complexity", "Rank"}
    if radon_columns.intersection(columns):
        return "radon_csv"

    return possible_by_name


def detect_file_type(path):
    """
    Clasifica cualquier archivo de resultados.
    """
    suffix = path.suffix.lower()

    if suffix == ".json":
        json_type = detect_json_type(path)
        if json_type == "pycefr":
            return "pycefr_json"
        if json_type == "radon":
            return "radon_json"
        return "json_unknown"

    if suffix == ".csv":
        return detect_csv_type(path)

    return "unknown"

# %% [markdown]
# ## Carpetas esperadas
#
# La estructura recomendada es:
#
# ```text
# data/
#   processed/
#     caso_1/
#     caso_2/
#     caso_3/
# ```
#
# Cada carpeta de caso puede contener los JSON o CSV generados por las herramientas.

# %%
print("BASE_DIR:", BASE_DIR)
print("PROCESSED_DIR existe:", PROCESSED_DIR.exists())
print("OUTPUT_DIR:", OUTPUT_DIR)
# Out:
# BASE_DIR: /home/juan/Documents/Analisis-CC-PyCEFR
# PROCESSED_DIR existe: True
# OUTPUT_DIR: /home/juan/Documents/Analisis-CC-PyCEFR/outputs

# %%
def find_case_folders():
    """
    Devuelve las carpetas de casos dentro de data/processed.
    Cada subcarpeta se considera un caso.
    """
    if not PROCESSED_DIR.exists():
        return []

    return sorted([p for p in PROCESSED_DIR.iterdir() if p.is_dir()])

# %%
case_folders = find_case_folders()
print("Número de proyectos a analizar:", len(case_folders))
for p in case_folders:
    print("-", p.name)
# Out:
# Número de proyectos a analizar: 5
# - 30-Days-Of-Python
# - Analisis-CC-PyCEFR
# - python-algorithms
# - python-beginner-programming-exercises
# - python-mini-projects

# %%
rows = []

for case_dir in case_folders:
    for path in sorted(case_dir.rglob("*")):
        if path.is_file() and path.suffix.lower() in [".json", ".csv"]:
            file_type = detect_file_type(path)

            rows.append({
                "case": case_dir.name,
                "file": path.name,
                "path": str(path),
                "extension": path.suffix.lower(),
                "detected_type": file_type,
                "size_kb": round(path.stat().st_size / 1024, 2),
            })

catalog = pd.DataFrame(rows)
catalog
# Out:
#                                      case  \
# 0                       30-Days-Of-Python
# 1                       30-Days-Of-Python
# 2                       30-Days-Of-Python
# 3                       30-Days-Of-Python
# 4                      Analisis-CC-PyCEFR
# 5                      Analisis-CC-PyCEFR
# 6                      Analisis-CC-PyCEFR
# 7                      Analisis-CC-PyCEFR
# 8                       python-algorithms
# 9                       python-algorithms
# 10                      python-algorithms
# 11                      python-algorithms
# 12  python-beginner-programming-exercises
# 13  python-beginner-programming-exercises
# 14  python-beginner-programming-exercises
# 15  python-beginner-programming-exercises
# 16                   python-mini-projects
# 17                   python-mini-projects
# 18                   python-mini-projects
# 19                   python-mini-projects
#
#                                                  file  \
# 0                                     data_pycefr.csv
# 1                                    data_pycefr.json
# 2                  radon_output_30-Days-Of-Python.csv
# 3                 radon_output_30-Days-Of-Python.json
# 4                                     data_pycefr.csv
# 5                                    data_pycefr.json
# 6                 radon_output_Analisis-CC-PyCEFR.csv
# 7                radon_output_Analisis-CC-PyCEFR.json
# 8                                     data_pycefr.csv
# 9                                    data_pycefr.json
# 10                 radon_output_python-algorithms.csv
# 11                radon_output_python-algorithms.json
# 12                                    data_pycefr.csv
# 13                                   data_pycefr.json
# 14  radon_output_python-beginner-programming-exerc...
# 15  radon_output_python-beginner-programming-exerc...
# 16                                    data_pycefr.csv
# 17                                   data_pycefr.json
# 18              radon_output_python-mini-projects.csv
# 19             radon_output_python-mini-projects.json
#
#                                                  path extension detected_type  \
# 0   /home/juan/Documents/Analisis-CC-PyCEFR/data/p...      .csv    pycefr_csv
# 1   /home/juan/Documents/Analisis-CC-PyCEFR/data/p...     .json   pycefr_json
# 2   /home/juan/Documents/Analisis-CC-PyCEFR/data/p...      .csv     radon_csv
# 3   /home/juan/Documents/Analisis-CC-PyCEFR/data/p...     .json    radon_json
# 4   /home/juan/Documents/Analisis-CC-PyCEFR/data/p...      .csv    pycefr_csv
# 5   /home/juan/Documents/Analisis-CC-PyCEFR/data/p...     .json   pycefr_json
# 6   /home/juan/Documents/Analisis-CC-PyCEFR/data/p...      .csv     radon_csv
# 7   /home/juan/Documents/Analisis-CC-PyCEFR/data/p...     .json    radon_json
# 8   /home/juan/Documents/Analisis-CC-PyCEFR/data/p...      .csv    pycefr_csv
# 9   /home/juan/Documents/Analisis-CC-PyCEFR/data/p...     .json   pycefr_json
# 10  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...      .csv     radon_csv
# 11  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...     .json    radon_json
# 12  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...      .csv    pycefr_csv
# 13  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...     .json   pycefr_json
# 14  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...      .csv     radon_csv
# 15  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...     .json    radon_json
# 16  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...      .csv    pycefr_csv
# 17  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...     .json   pycefr_json
# 18  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...      .csv     radon_csv
# 19  /home/juan/Documents/Analisis-CC-PyCEFR/data/p...     .json    radon_json
#
#     size_kb
# 0     70.00
# 1    278.81
# 2      1.39
# 3      6.96
# 4     22.44
# 5     99.68
# 6      1.13
# 7      4.89
# 8   1631.76
# 9   4516.54
# 10   106.51
# 11   711.76
# 12    67.03
# 13   242.52
# 14    10.03
# 15    38.13
# 16   662.79
# 17  2259.24
# 18    22.27
# 19   145.46

# %%
catalog.to_csv(OUTPUT_DIR / "00_catalogo_ficheros.csv", index=False)

summary_catalog = (
    catalog
    .groupby(["case"])
    .size()
    .reset_index(name="n_files")
)

summary_catalog
# Out:
#                                     case  n_files
# 0                      30-Days-Of-Python        4
# 1                     Analisis-CC-PyCEFR        4
# 2                      python-algorithms        4
# 3  python-beginner-programming-exercises        4
# 4                   python-mini-projects        4

# %%
# Compruebo qué casos tienen resultados de las dos herramientas 
case_status = (
    catalog
    .groupby("case")
    .agg(
        n_files=("file", "count"),
        has_pycefr=("detected_type", lambda x: any(k.startswith("pycefr") for k in x)),
        has_radon=("detected_type", lambda x: any(k.startswith("radon") for k in x)),
        has_pycefr_json=("detected_type", lambda x: "pycefr_json" in set(x)),
        has_radon_json=("detected_type", lambda x: "radon_json" in set(x)),
        has_pycefr_csv=("detected_type", lambda x: "pycefr_csv" in set(x)),
        has_radon_csv=("detected_type", lambda x: "radon_csv" in set(x)),
    )
    .reset_index()
)

case_status["is_comparable"] = case_status["has_pycefr"] & case_status["has_radon"]

case_status
# Out:
#                                     case  n_files  has_pycefr  has_radon  \
# 0                      30-Days-Of-Python        4        True       True
# 1                     Analisis-CC-PyCEFR        4        True       True
# 2                      python-algorithms        4        True       True
# 3  python-beginner-programming-exercises        4        True       True
# 4                   python-mini-projects        4        True       True
#
#    has_pycefr_json  has_radon_json  has_pycefr_csv  has_radon_csv  \
# 0             True            True            True           True
# 1             True            True            True           True
# 2             True            True            True           True
# 3             True            True            True           True
# 4             True            True            True           True
#
#    is_comparable
# 0           True
# 1           True
# 2           True
# 3           True
# 4           True
