# %% [markdown]
# # 05 - Casos interesantes
#
# Este notebook busca automáticamente funciones útiles para comentar en la memoria.
#
# No busco solo las funciones más complejas. También quiero ejemplos donde las dos herramientas digan cosas distintas.

# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt

BASE_DIR = Path("..").resolve()
OUTPUT_DIR = BASE_DIR / "outputs"
FIGURES_DIR = OUTPUT_DIR / "figures"
FIGURES_DIR.mkdir(parents=True, exist_ok=True)

df_pycefr = pd.read_csv(OUTPUT_DIR / "pycefr_constructs_global.csv")
df_radon = pd.read_csv(OUTPUT_DIR / "radon_functions_global.csv")

def label_interesting_cases(cross):
    df = cross.copy()
    if df.empty:
        df["case_type"] = []
        return df
    conditions = []
    for _, row in df.iterrows():
        labels = []
        if row.get("radon_grade_num", 0) >= 2 and row.get("max_level_num", 0) <= 2:
            labels.append("Radon alto / PyCEFR bajo")
        if row.get("radon_grade_num", 0) <= 1 and row.get("max_level_num", 0) >= 5:
            labels.append("PyCEFR alto / Radon bajo")
        if row.get("radon_grade_num", 0) >= 2 and row.get("max_level_num", 0) >= 4:
            labels.append("Coincidencia en dificultad alta")
        if row.get("n_pycefr_constructs", 0) >= 25 and row.get("max_level_num", 0) <= 2:
            labels.append("Muchos constructos simples acumulados")
        if not labels:
            labels.append("Sin patrón destacado")
        conditions.append("; ".join(labels))
    df["case_type"] = conditions
    return df

# %%
cross = pd.read_csv(OUTPUT_DIR / "04_radon_pycefr_cross_global.csv")

# Compatibilidad por si existe una tabla antigua con la columna original de Radon
if "radon_grade" not in cross.columns and "rank" in cross.columns:
    cross["radon_grade"] = cross["rank"]
if "radon_grade_num" not in cross.columns and "rank_num" in cross.columns:
    cross["radon_grade_num"] = cross["rank_num"]

interesting = label_interesting_cases(cross)
interesting.head()
# Out:
#                 case                                               file  \
# 0  30-Days-Of-Python  /home/juan/Documents/Analisis-CC-PyCEFR/30-Day...
# 1  30-Days-Of-Python  /home/juan/Documents/Analisis-CC-PyCEFR/30-Day...
# 2  30-Days-Of-Python  /home/juan/Documents/Analisis-CC-PyCEFR/30-Day...
# 3  30-Days-Of-Python  /home/juan/Documents/Analisis-CC-PyCEFR/30-Day...
# 4  30-Days-Of-Python  /home/juan/Documents/Analisis-CC-PyCEFR/30-Day...
#
#        file_name            function parent  lineno  endline  complexity  \
# 0    mymodule.py  generate_full_name    NaN       1        4           1
# 1    mymodule.py        sum_two_nums    NaN       7        8           1
# 2    mymodule.py  generate_full_name    NaN       1        4           1
# 3    mymodule.py        sum_two_nums    NaN       6        7           1
# 4  arithmetic.py         add_numbers    NaN       1        5           2
#
#   radon_grade  radon_grade_num  n_pycefr_constructs  n_pycefr_classes  \
# 0           A                1                    8                 4
# 1           A                1                    4                 3
# 2           A                1                    8                 4
# 3           A                1                    2                 2
# 4           A                1                    5                 5
#
#    max_level_num max_level  mean_level_num                 level_counts  \
# 0            1.0        A1             1.0                    {"A1": 8}
# 1            1.0        A1             1.0                    {"A1": 4}
# 2            1.0        A1             1.0                    {"A1": 8}
# 3            1.0        A1             1.0                    {"A1": 2}
# 4            3.0        B1             1.6  {"A1": 3, "A2": 1, "B1": 1}
#
#                                          top_classes             case_type
# 0  {"Simple Assignment": 2, "Assigment with sum (...  Sin patrón destacado
# 1  {"Return": 2, "Simple Assignment": 1, "Functio...  Sin patrón destacado
# 2  {"Simple Assignment": 2, "Assigment with sum (...  Sin patrón destacado
# 3  {"Function with Simple argument": 1, "Return": 1}  Sin patrón destacado
# 4  {"Simple Assignment": 1, "Simplified increment...  Sin patrón destacado

# %%
interesting["case_type"].value_counts()
# Out:
# case_type
# Sin patrón destacado                                               1596
# PyCEFR alto / Radon bajo                                            196
# Coincidencia en dificultad alta                                      82
# Muchos constructos simples acumulados                                64
# Radon alto / PyCEFR bajo; Muchos constructos simples acumulados      18
# Radon alto / PyCEFR bajo                                              5
# Name: count, dtype: int64

# %%
selected = interesting[interesting["case_type"] != "Sin patrón destacado"].copy()
selected = selected.sort_values(["case_type", "complexity", "max_level_num", "n_pycefr_constructs"], ascending=[True, False, False, False])
selected.head(50)
# Out:
#                       case                                               file  \
# 1638  python-mini-projects  /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 1824  python-mini-projects  /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 1946  python-mini-projects  /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 1850  python-mini-projects  /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 1714  python-mini-projects  /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 983      python-algorithms  /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 1934  python-mini-projects  /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 395      python-algorithms  /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 695      python-algorithms  /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 1929  python-mini-projects  /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 1856  python-mini-projects  /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 426      python-algorithms  /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 414      python-algorithms  /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 618      python-algorithms  /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 624      python-algorithms  /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 628      python-algorithms  /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 622      python-algorithms  /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 199      python-algorithms  /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 200      python-algorithms  /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 984      python-algorithms  /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 1930  python-mini-projects  /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 1733  python-mini-projects  /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 24      Analisis-CC-PyCEFR  /home/juan/Documents/Analisis-CC-PyCEFR/Analis...
# 51       python-algorithms  /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 626      python-algorithms  /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 630      python-algorithms  /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 421      python-algorithms  /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 1434     python-algorithms  /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 25      Analisis-CC-PyCEFR  /home/juan/Documents/Analisis-CC-PyCEFR/Analis...
# 1511     python-algorithms  /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 1825  python-mini-projects  /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 427      python-algorithms  /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 862      python-algorithms  /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 27      Analisis-CC-PyCEFR  /home/juan/Documents/Analisis-CC-PyCEFR/Analis...
# 179      python-algorithms  /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 699      python-algorithms  /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 710      python-algorithms  /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 858      python-algorithms  /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 134      python-algorithms  /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 1688  python-mini-projects  /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 1689  python-mini-projects  /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 1245     python-algorithms  /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 103      python-algorithms  /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 435      python-algorithms  /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 181      python-algorithms  /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 112      python-algorithms  /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 712      python-algorithms  /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 72       python-algorithms  /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 148      python-algorithms  /home/juan/Documents/Analisis-CC-PyCEFR/python...
# 327      python-algorithms  /home/juan/Documents/Analisis-CC-PyCEFR/python...
#
#                                 file_name                    function  \
# 1638                         converter.py                   converter
# 1824                               bot.py                  on_message
# 1946                              main.py                       fetch
# 1850                           hangman.py                        play
# 1714                    tic-tac-toe-AI.py                      CompAI
# 983                           avl_tree.py                  deleteNode
# 1934                             utils.py               build_dataset
# 395             merge_two_binary_trees.py            mergeTreesHelper
# 695            median_in_sorted_arrays.py                merge_arrays
# 1929                             model.py                       Model
# 1856                  movieInfoScraper.py             getMovieDetails
# 426                   detect_cycle_bfs.py                    is_cycle
# 414               minimum_height_trees.py          findMinHeightTrees
# 618              task_scheduling_order.py                  find_order
# 624            course_scheduling_order.py                  find_order
# 628                   topological_sort.py            topological_sort
# 622                         find_cycle.py            topological_sort
# 199                    delete_bst_node.py                 delete_node
# 200                    delete_bst_node.py               delete_node_2
# 984                           avl_tree.py                  insertNode
# 1930                             model.py                    __init__
# 1733                             alarm.py                   set_alarm
# 24                           generator.py             extract_records
# 51                topological_sort_bfs.py            topological_sort
# 626                  course_scheduling.py      is_scheduling_possible
# 630                    task_scheduling.py      is_scheduling_possible
# 421                bfs_khans_algorithm.py                    top_sort
# 1434                               lca.py                         lca
# 25                           generator.py                        walk
# 1511                       search_maze.py          search_maze_helper
# 1825                               bot.py                       MyBot
# 427                    shortest_path_1.py               shortest_path
# 862              sliding_window_median.py  find_sliding_window_median
# 27                           generator.py                   read_json
# 179                           path_sum.py             path_sum_helper
# 699              smallest_number_range.py         find_smallest_range
# 710                  k_smallest_number.py           find_Kth_smallest
# 858                      next_interval.py          find_next_interval
# 134                              top_k.py                topKFrequent
# 1688                               dct.py                      insert
# 1689                               dct.py                     extract
# 1245                      solve_sudoku.py                         dfs
# 103            subtree_of_another_tree.py                   same_tree
# 435            ninja_training_top_down.py                       solve
# 181            subtree_of_another_tree.py                is_same_tree
# 112                          same_tree.py                   same_tree
# 712   number_factors_top_down_approach.py        count_ways_recursive
# 72                          quick_sort.py           quick_sort_helper
# 148                     partition_to_k.py                   backtrack
# 327                          same_tree.py            same_tree_helper
#
#                      parent  lineno  endline  complexity radon_grade  \
# 1638                    NaN      19       72          34           E
# 1824                    NaN      41      171          34           E
# 1946                    NaN      15       82          17           C
# 1850                    NaN      16      101          16           C
# 1714                    NaN      95      124          14           C
# 983                     NaN     190      222          14           C
# 1934                    NaN      59       80          13           C
# 395             merge_trees       9       23          13           C
# 695                     NaN      13       48          12           C
# 1929                    NaN       6      131          11           C
# 1856                    NaN       7       82          11           C
# 426                     NaN       6       29          11           C
# 414                     NaN       2       35          11           C
# 618                     NaN      12       46          11           C
# 624                     NaN      12       46          11           C
# 628                     NaN      13       48          11           C
# 622                     NaN      13       47          11           C
# 199                     NaN       5       26          11           C
# 200                     NaN      32       53          11           C
# 984                     NaN     158      183          11           C
# 1930                    NaN       7      131          10           B
# 1733                    NaN      18       66          10           B
# 24                      NaN     206      248          10           B
# 51                      NaN      13       45          10           B
# 626                     NaN      14       48          10           B
# 630                     NaN      14       48          10           B
# 421                     NaN       3       25          10           B
# 1434                    NaN       6       37          10           B
# 25          extract_records     228      245          10           B
# 1511            search_maze       4       22           9           B
# 1825                    NaN      24      229           8           B
# 427                     NaN       6       41           8           B
# 862                     NaN      22       49           8           B
# 27                      NaN      66      157           8           B
# 179              path_sum_2      27       42           8           B
# 699                     NaN      14       37           7           B
# 710                     NaN      13       34           7           B
# 858                     NaN       8       27           7           B
# 134                     NaN       5       20           7           B
# 1688                    NaN      32       64           7           B
# 1689                    NaN      93      120           7           B
# 1245            solveSudoku      20       47           7           B
# 103                     NaN      12       18           7           B
# 435                     NaN       9       25           7           B
# 181                     NaN      11       16           7           B
# 112                     NaN       1        8           7           B
# 712                     NaN      32       51           7           B
# 72                      NaN       8       28           7           B
# 148   can_partion_k_subsets       8       26           7           B
# 327               same_tree       8       18           7           B
#
#       radon_grade_num  n_pycefr_constructs  n_pycefr_classes  max_level_num  \
# 1638                5                  141                20            6.0
# 1824                5                  180                16            5.0
# 1946                3                  663                40            6.0
# 1850                3                   62                16            6.0
# 1714                3                   33                13            6.0
# 983                 3                   61                 7            4.0
# 1934                3                   37                11            5.0
# 395                 3                   28                 8            4.0
# 695                 3                   38                17            6.0
# 1929                3                  355                20            6.0
# 1856                3                  116                12            5.0
# 426                 3                   52                17            5.0
# 414                 3                   46                15            5.0
# 618                 3                   43                14            5.0
# 624                 3                   43                14            5.0
# 628                 3                   43                14            5.0
# 622                 3                   42                14            5.0
# 199                 3                   48                 8            4.0
# 200                 3                   48                 8            4.0
# 984                 3                   46                 8            4.0
# 1930                2                  351                18            6.0
# 1733                2                   69                16            6.0
# 24                  2                   50                16            5.0
# 51                  2                   40                14            5.0
# 626                 2                   39                14            5.0
# 630                 2                   39                14            5.0
# 421                 2                   32                15            5.0
# 1434                2                   67                14            4.0
# 25                  2                   18                 9            4.0
# 1511                2                   28                11            4.0
# 1825                2                  230                22            6.0
# 427                 2                   59                14            5.0
# 862                 2                   49                12            5.0
# 27                  2                   47                18            5.0
# 179                 2                   20                 7            4.0
# 699                 2                   34                13            6.0
# 710                 2                   24                14            6.0
# 858                 2                   45                14            5.0
# 134                 2                   26                16            5.0
# 1688                2                   68                14            4.0
# 1689                2                   51                17            4.0
# 1245                2                   42                12            4.0
# 103                 2                   33                 6            4.0
# 435                 2                   30                 8            4.0
# 181                 2                   27                 6            4.0
# 112                 2                   24                 9            4.0
# 712                 2                   23                 7            4.0
# 72                  2                   21                10            4.0
# 148                 2                   20                 9            4.0
# 327                 2                   18                 5            4.0
#
#      max_level  mean_level_num  \
# 1638        C2        1.446809
# 1824        C1        1.516667
# 1946        C2        1.597285
# 1850        C2        1.322581
# 1714        C2        1.545455
# 983         B2        1.442623
# 1934        C1        2.108108
# 395         B2        1.821429
# 695         C2        1.526316
# 1929        C2        1.704225
# 1856        C1        1.629310
# 426         C1        1.403846
# 414         C1        1.500000
# 618         C1        1.441860
# 624         C1        1.441860
# 628         C1        1.441860
# 622         C1        1.452381
# 199         B2        1.562500
# 200         B2        1.562500
# 984         B2        1.500000
# 1930        C2        1.703704
# 1733        C2        1.463768
# 24          C1        1.360000
# 51          C1        1.475000
# 626         C1        1.487179
# 630         C1        1.487179
# 421         C1        1.531250
# 1434        B2        1.343284
# 25          B2        1.333333
# 1511        B2        1.142857
# 1825        C2        1.552174
# 427         C1        1.254237
# 862         C1        1.448980
# 27          C1        1.829787
# 179         B2        1.400000
# 699         C2        1.411765
# 710         C2        1.541667
# 858         C1        1.244444
# 134         C1        1.500000
# 1688        B2        1.470588
# 1689        B2        1.509804
# 1245        B2        1.333333
# 103         B2        1.454545
# 435         B2        1.166667
# 181         B2        1.481481
# 112         B2        1.583333
# 712         B2        1.130435
# 72          B2        1.333333
# 148         B2        1.300000
# 327         B2        1.500000
#
#                                            level_counts  \
# 1638   {"A1": 99, "A2": 29, "B1": 10, "C2": 2, "C1": 1}
# 1824             {"A1": 92, "A2": 85, "B1": 2, "C1": 1}
# 1946  {"A1": 317, "A2": 307, "B1": 31, "B2": 6, "C2"...
# 1850     {"A1": 50, "A2": 9, "C2": 1, "C1": 1, "B1": 1}
# 1714              {"A1": 28, "C1": 3, "C2": 1, "A2": 1}
# 983                       {"A1": 36, "A2": 24, "B2": 1}
# 1934              {"A1": 24, "C1": 9, "A2": 3, "B1": 1}
# 395               {"A1": 13, "A2": 8, "B1": 6, "B2": 1}
# 695      {"A1": 28, "A2": 5, "B1": 3, "C2": 1, "C1": 1}
# 1929  {"A2": 217, "A1": 127, "B1": 6, "C1": 4, "C2": 1}
# 1856             {"A1": 58, "A2": 51, "C1": 4, "B1": 3}
# 426              {"A1": 36, "A2": 13, "B1": 2, "C1": 1}
# 414              {"A1": 30, "A2": 13, "C1": 2, "B1": 1}
# 618               {"A1": 31, "A2": 9, "C1": 2, "B1": 1}
# 624               {"A1": 31, "A2": 9, "C1": 2, "B1": 1}
# 628               {"A1": 31, "A2": 9, "C1": 2, "B1": 1}
# 622               {"A1": 30, "A2": 9, "C1": 2, "B1": 1}
# 199              {"A1": 24, "A2": 22, "B1": 1, "B2": 1}
# 200              {"A1": 24, "A2": 22, "B1": 1, "B2": 1}
# 984                       {"A1": 25, "A2": 20, "B2": 1}
# 1930  {"A2": 216, "A1": 125, "B1": 5, "C1": 4, "C2": 1}
# 1733             {"A1": 46, "A2": 17, "B1": 5, "C2": 1}
# 24       {"A1": 39, "A2": 7, "B1": 2, "C1": 1, "B2": 1}
# 51                {"A1": 28, "A2": 9, "C1": 2, "B1": 1}
# 626               {"A1": 27, "A2": 9, "C1": 2, "B1": 1}
# 630               {"A1": 27, "A2": 9, "C1": 2, "B1": 1}
# 421               {"A1": 20, "A2": 9, "B1": 2, "C1": 1}
# 1434             {"A1": 49, "A2": 14, "B1": 3, "B2": 1}
# 25                         {"A1": 14, "A2": 3, "B2": 1}
# 1511                       {"A1": 26, "A2": 1, "B2": 1}
# 1825  {"A1": 116, "A2": 107, "B1": 4, "C2": 1, "C1":...
# 427               {"A1": 49, "A2": 7, "B1": 2, "C1": 1}
# 862                       {"A1": 30, "A2": 18, "C1": 1}
# 27               {"A2": 23, "A1": 17, "B1": 6, "C1": 1}
# 179                        {"A1": 14, "A2": 5, "B2": 1}
# 699      {"A1": 28, "A2": 3, "C2": 1, "C1": 1, "B1": 1}
# 710      {"A1": 19, "A2": 2, "C2": 1, "C1": 1, "B1": 1}
# 858               {"A1": 38, "A2": 5, "C1": 1, "B1": 1}
# 134                        {"A1": 16, "A2": 9, "C1": 1}
# 1688                      {"A1": 38, "A2": 29, "B2": 1}
# 1689             {"A1": 30, "A2": 17, "B1": 3, "B2": 1}
# 1245              {"A1": 31, "A2": 9, "B1": 1, "B2": 1}
# 103                       {"A1": 20, "A2": 12, "B2": 1}
# 435                        {"A1": 27, "A2": 2, "B2": 1}
# 181                       {"A1": 16, "A2": 10, "B2": 1}
# 112               {"A1": 13, "A2": 9, "B2": 1, "B1": 1}
# 712                                 {"A1": 22, "B2": 1}
# 72                {"A1": 17, "A2": 2, "B1": 1, "B2": 1}
# 148               {"A1": 17, "A2": 1, "B1": 1, "B2": 1}
# 327                        {"A1": 11, "A2": 6, "B2": 1}
#
#                                             top_classes  \
# 1638  {"Subscript": 42, "Simple Atributte": 23, "Sim...
# 1824  {"Simple Atributte": 85, "Simple If statements...
# 1946  {"Simple Atributte": 263, "Simple Assignment":...
# 1850  {"Print": 19, "Simple Assignment": 12, "Simple...
# 1714  {"Simple Assignment": 10, "Simple If statement...
# 983   {"Simple Atributte": 24, "Simple Assignment": ...
# 1934  {"Simple Assignment": 10, "Simple List Compreh...
# 395   {"Simple Atributte": 8, "If statements express...
# 695   {"Simple Assignment": 12, "Simple Tuple": 4, "...
# 1929  {"Simple Atributte": 209, "Simple Assignment":...
# 1856  {"Simple Atributte": 42, "Simple Assignment": ...
# 426   {"Simple Assignment": 9, "Simple Atributte": 7...
# 414   {"Subscript": 10, "Simple Assignment": 7, "Sim...
# 618   {"Subscript": 8, "Simple Assignment": 6, "Simp...
# 624   {"Subscript": 8, "Simple Assignment": 6, "Simp...
# 628   {"Subscript": 8, "Simple Assignment": 6, "Simp...
# 622   {"Subscript": 8, "Simple Assignment": 6, "Simp...
# 199   {"Simple Atributte": 22, "Simple Assignment": ...
# 200   {"Simple Atributte": 22, "Simple Assignment": ...
# 984   {"Simple Atributte": 20, "Simple If statements...
# 1930  {"Simple Atributte": 209, "Simple Assignment":...
# 1733  {"Simple Atributte": 16, "Simple Assignment": ...
# 24    {"Simple If statements": 10, "Simple Assignmen...
# 51    {"Subscript": 8, "Simple Assignment": 6, "Simp...
# 626   {"Subscript": 8, "Simple Assignment": 6, "Simp...
# 630   {"Subscript": 8, "Simple Assignment": 6, "Simp...
# 421   {"Subscript": 6, "Simple Assignment": 5, "Simp...
# 1434  {"Simple Assignment": 17, "Simple Atributte": ...
# 25    {"Simple If statements": 5, "Simple Assignment...
# 1511  {"Subscript": 6, "Simple List": 4, "Return": 4...
# 1825  {"Simple Atributte": 107, "Simple If statement...
# 427   {"Subscript": 11, "Simple Assignment": 11, "Si...
# 862   {"Simple Atributte": 16, "Subscript": 11, "Una...
# 27    {"Simple Atributte": 17, "Simple Assignment": ...
# 179   {"Simple Atributte": 5, "Return": 5, "Simple I...
# 699   {"Simple Assignment": 11, "Simple Tuple": 8, "...
# 710   {"Simple Assignment": 7, "Simple Tuple": 4, "S...
# 858   {"Simple Tuple": 8, "Simple Assignment": 8, "U...
# 134   {"Simple Atributte": 4, "Subscript": 3, "Simpl...
# 1688  {"Simple Atributte": 20, "Simple Assignment": ...
# 1689  {"Simple Atributte": 10, "Simple Assignment": ...
# 1245  {"Subscript": 14, "Simple Atributte": 8, "Simp...
# 103   {"Simple Atributte": 12, "Boolean Operation": ...
# 435   {"Subscript": 12, "Simple Assignment": 5, "Sim...
# 181   {"Simple Atributte": 10, "Boolean Operation": ...
# 112   {"Simple Atributte": 9, "Boolean Operation": 3...
# 712   {"Return": 7, "Simple If statements": 6, "Subs...
# 72    {"Subscript": 8, "Simple If statements": 4, "S...
# 148   {"Subscript": 4, "Simple If statements": 4, "R...
# 327   {"Simple Atributte": 6, "Return": 5, "Boolean ...
#
#                             case_type
# 1638  Coincidencia en dificultad alta
# 1824  Coincidencia en dificultad alta
# 1946  Coincidencia en dificultad alta
# 1850  Coincidencia en dificultad alta
# 1714  Coincidencia en dificultad alta
# 983   Coincidencia en dificultad alta
# 1934  Coincidencia en dificultad alta
# 395   Coincidencia en dificultad alta
# 695   Coincidencia en dificultad alta
# 1929  Coincidencia en dificultad alta
# 1856  Coincidencia en dificultad alta
# 426   Coincidencia en dificultad alta
# 414   Coincidencia en dificultad alta
# 618   Coincidencia en dificultad alta
# 624   Coincidencia en dificultad alta
# 628   Coincidencia en dificultad alta
# 622   Coincidencia en dificultad alta
# 199   Coincidencia en dificultad alta
# 200   Coincidencia en dificultad alta
# 984   Coincidencia en dificultad alta
# 1930  Coincidencia en dificultad alta
# 1733  Coincidencia en dificultad alta
# 24    Coincidencia en dificultad alta
# 51    Coincidencia en dificultad alta
# 626   Coincidencia en dificultad alta
# 630   Coincidencia en dificultad alta
# 421   Coincidencia en dificultad alta
# 1434  Coincidencia en dificultad alta
# 25    Coincidencia en dificultad alta
# 1511  Coincidencia en dificultad alta
# 1825  Coincidencia en dificultad alta
# 427   Coincidencia en dificultad alta
# 862   Coincidencia en dificultad alta
# 27    Coincidencia en dificultad alta
# 179   Coincidencia en dificultad alta
# 699   Coincidencia en dificultad alta
# 710   Coincidencia en dificultad alta
# 858   Coincidencia en dificultad alta
# 134   Coincidencia en dificultad alta
# 1688  Coincidencia en dificultad alta
# 1689  Coincidencia en dificultad alta
# 1245  Coincidencia en dificultad alta
# 103   Coincidencia en dificultad alta
# 435   Coincidencia en dificultad alta
# 181   Coincidencia en dificultad alta
# 112   Coincidencia en dificultad alta
# 712   Coincidencia en dificultad alta
# 72    Coincidencia en dificultad alta
# 148   Coincidencia en dificultad alta
# 327   Coincidencia en dificultad alta

# %%
# Top de ejemplos para revisar a mano
cols = ["case", "file_name", "function", "lineno", "endline", "complexity", "radon_grade", "max_level", "n_pycefr_constructs", "case_type", "top_classes"]
examples = selected[cols].head(30)
examples
# Out:
#                       case                   file_name  \
# 1638  python-mini-projects                converter.py
# 1824  python-mini-projects                      bot.py
# 1946  python-mini-projects                     main.py
# 1850  python-mini-projects                  hangman.py
# 1714  python-mini-projects           tic-tac-toe-AI.py
# 983      python-algorithms                 avl_tree.py
# 1934  python-mini-projects                    utils.py
# 395      python-algorithms   merge_two_binary_trees.py
# 695      python-algorithms  median_in_sorted_arrays.py
# 1929  python-mini-projects                    model.py
# 1856  python-mini-projects         movieInfoScraper.py
# 426      python-algorithms         detect_cycle_bfs.py
# 414      python-algorithms     minimum_height_trees.py
# 618      python-algorithms    task_scheduling_order.py
# 624      python-algorithms  course_scheduling_order.py
# 628      python-algorithms         topological_sort.py
# 622      python-algorithms               find_cycle.py
# 199      python-algorithms          delete_bst_node.py
# 200      python-algorithms          delete_bst_node.py
# 984      python-algorithms                 avl_tree.py
# 1930  python-mini-projects                    model.py
# 1733  python-mini-projects                    alarm.py
# 24      Analisis-CC-PyCEFR                generator.py
# 51       python-algorithms     topological_sort_bfs.py
# 626      python-algorithms        course_scheduling.py
# 630      python-algorithms          task_scheduling.py
# 421      python-algorithms      bfs_khans_algorithm.py
# 1434     python-algorithms                      lca.py
# 25      Analisis-CC-PyCEFR                generator.py
# 1511     python-algorithms              search_maze.py
#
#                     function  lineno  endline  complexity radon_grade  \
# 1638               converter      19       72          34           E
# 1824              on_message      41      171          34           E
# 1946                   fetch      15       82          17           C
# 1850                    play      16      101          16           C
# 1714                  CompAI      95      124          14           C
# 983               deleteNode     190      222          14           C
# 1934           build_dataset      59       80          13           C
# 395         mergeTreesHelper       9       23          13           C
# 695             merge_arrays      13       48          12           C
# 1929                   Model       6      131          11           C
# 1856         getMovieDetails       7       82          11           C
# 426                 is_cycle       6       29          11           C
# 414       findMinHeightTrees       2       35          11           C
# 618               find_order      12       46          11           C
# 624               find_order      12       46          11           C
# 628         topological_sort      13       48          11           C
# 622         topological_sort      13       47          11           C
# 199              delete_node       5       26          11           C
# 200            delete_node_2      32       53          11           C
# 984               insertNode     158      183          11           C
# 1930                __init__       7      131          10           B
# 1733               set_alarm      18       66          10           B
# 24           extract_records     206      248          10           B
# 51          topological_sort      13       45          10           B
# 626   is_scheduling_possible      14       48          10           B
# 630   is_scheduling_possible      14       48          10           B
# 421                 top_sort       3       25          10           B
# 1434                     lca       6       37          10           B
# 25                      walk     228      245          10           B
# 1511      search_maze_helper       4       22           9           B
#
#      max_level  n_pycefr_constructs                        case_type  \
# 1638        C2                  141  Coincidencia en dificultad alta
# 1824        C1                  180  Coincidencia en dificultad alta
# 1946        C2                  663  Coincidencia en dificultad alta
# 1850        C2                   62  Coincidencia en dificultad alta
# 1714        C2                   33  Coincidencia en dificultad alta
# 983         B2                   61  Coincidencia en dificultad alta
# 1934        C1                   37  Coincidencia en dificultad alta
# 395         B2                   28  Coincidencia en dificultad alta
# 695         C2                   38  Coincidencia en dificultad alta
# 1929        C2                  355  Coincidencia en dificultad alta
# 1856        C1                  116  Coincidencia en dificultad alta
# 426         C1                   52  Coincidencia en dificultad alta
# 414         C1                   46  Coincidencia en dificultad alta
# 618         C1                   43  Coincidencia en dificultad alta
# 624         C1                   43  Coincidencia en dificultad alta
# 628         C1                   43  Coincidencia en dificultad alta
# 622         C1                   42  Coincidencia en dificultad alta
# 199         B2                   48  Coincidencia en dificultad alta
# 200         B2                   48  Coincidencia en dificultad alta
# 984         B2                   46  Coincidencia en dificultad alta
# 1930        C2                  351  Coincidencia en dificultad alta
# 1733        C2                   69  Coincidencia en dificultad alta
# 24          C1                   50  Coincidencia en dificultad alta
# 51          C1                   40  Coincidencia en dificultad alta
# 626         C1                   39  Coincidencia en dificultad alta
# 630         C1                   39  Coincidencia en dificultad alta
# 421         C1                   32  Coincidencia en dificultad alta
# 1434        B2                   67  Coincidencia en dificultad alta
# 25          B2                   18  Coincidencia en dificultad alta
# 1511        B2                   28  Coincidencia en dificultad alta
#
#                                             top_classes
# 1638  {"Subscript": 42, "Simple Atributte": 23, "Sim...
# 1824  {"Simple Atributte": 85, "Simple If statements...
# 1946  {"Simple Atributte": 263, "Simple Assignment":...
# 1850  {"Print": 19, "Simple Assignment": 12, "Simple...
# 1714  {"Simple Assignment": 10, "Simple If statement...
# 983   {"Simple Atributte": 24, "Simple Assignment": ...
# 1934  {"Simple Assignment": 10, "Simple List Compreh...
# 395   {"Simple Atributte": 8, "If statements express...
# 695   {"Simple Assignment": 12, "Simple Tuple": 4, "...
# 1929  {"Simple Atributte": 209, "Simple Assignment":...
# 1856  {"Simple Atributte": 42, "Simple Assignment": ...
# 426   {"Simple Assignment": 9, "Simple Atributte": 7...
# 414   {"Subscript": 10, "Simple Assignment": 7, "Sim...
# 618   {"Subscript": 8, "Simple Assignment": 6, "Simp...
# 624   {"Subscript": 8, "Simple Assignment": 6, "Simp...
# 628   {"Subscript": 8, "Simple Assignment": 6, "Simp...
# 622   {"Subscript": 8, "Simple Assignment": 6, "Simp...
# 199   {"Simple Atributte": 22, "Simple Assignment": ...
# 200   {"Simple Atributte": 22, "Simple Assignment": ...
# 984   {"Simple Atributte": 20, "Simple If statements...
# 1930  {"Simple Atributte": 209, "Simple Assignment":...
# 1733  {"Simple Atributte": 16, "Simple Assignment": ...
# 24    {"Simple If statements": 10, "Simple Assignmen...
# 51    {"Subscript": 8, "Simple Assignment": 6, "Simp...
# 626   {"Subscript": 8, "Simple Assignment": 6, "Simp...
# 630   {"Subscript": 8, "Simple Assignment": 6, "Simp...
# 421   {"Subscript": 6, "Simple Assignment": 5, "Simp...
# 1434  {"Simple Assignment": 17, "Simple Atributte": ...
# 25    {"Simple If statements": 5, "Simple Assignment...
# 1511  {"Subscript": 6, "Simple List": 4, "Return": 4...

# %%
interesting.to_csv(OUTPUT_DIR / "05_casos_interesantes_global.csv", index=False)
examples.to_csv(OUTPUT_DIR / "05_ejemplos_para_memoria.csv", index=False)
print("Guardado:", OUTPUT_DIR / "05_ejemplos_para_memoria.csv")
# Out:
# Guardado: /home/juan/Documents/Analisis-CC-PyCEFR/outputs/05_ejemplos_para_memoria.csv
